# %%
from quimb import *
from quimb.tensor import *
import quimb as qu
import numpy as np
import quimb.tensor as qtn
import quf
import matplotlib.pyplot as plt
from numpy import linalg as LA
import math
# Out:
# /Users/reza/cotengra/cotengra/hyper.py:19: UserWarning: Couldn't import `kahypar` - skipping from default hyper optimizer and using basic `labels` method instead.
#   warnings.warn("Couldn't import `kahypar` - skipping from default "

# %%
L_L=32
D=2

#mps = MPS_rand_state(L=16, bond_dim=10)
#qmps, list_qmps_brickwall=quf.qmps_f(L=L_L,in_depth=4,n_Qbit=2, qmps_structure="pollmann", canon="left", n_q_mera=2, internal_mera="brickwall")


#mps, tags=quf.brickwall_circuit( L=L_L, in_depth=1, n_Qbit=2, depth_total=8, qmps_structure="brickwall", n_q_mera=2 )
#mps, tags=quf.pollmann_circuit( L=L_L, in_depth=1, n_Qbit=2, depth_total=8, qmps_structure="pollmann", n_q_mera=2 )
qmera,tag=quf.qmera_f(L=L_L,in_depth=2,n_Qbit=2,depth_total=int(math.log2(L_L)),qmera_type='brickwall') 

#qmera = qtn.MERA.rand(L_L, max_bond=D, dtype='float64')
#qmera.add_tag("U", which='all')
#qmera.unitize_()




qmera.draw( color=[f"lay{i}" for i in range(L_L)], iterations=600, figsize=(50, 50),  legend=False, return_fig=False,node_size=1200 , edge_scale=7, initial_layout='spectral', edge_alpha=0.833)
#plt.savefig('fig.pdf')
#plt.clf()
# Out:
# 1_Qubit [0, 1] site= 0 layer= 0 max_bond= 2
# G_e 0 1 0
# 1_Qubit [2, 3] site= 2 layer= 0 max_bond= 2
# G_e 2 3 1
# 1_Qubit [4, 5] site= 4 layer= 0 max_bond= 2
# G_e 4 5 2
# 1_Qubit [6, 7] site= 6 layer= 0 max_bond= 2
# G_e 6 7 3
# 1_Qubit [8, 9] site= 8 layer= 0 max_bond= 2
# G_e 8 9 4
# 1_Qubit [10, 11] site= 10 layer= 0 max_bond= 2
# G_e 10 11 5
# 1_Qubit [12, 13] site= 12 layer= 0 max_bond= 2
# G_e 12 13 6
# 1_Qubit [14, 15] site= 14 layer= 0 max_bond= 2
# G_e 14 15 7
# 1_Qubit [16, 17] site= 16 layer= 0 max_bond= 2
# G_e 16 17 8
# 1_Qubit [18, 19] site= 18 layer= 0 max_bond= 2
# G_e 18 19 9
# 1_Qubit [20, 21] site= 20 layer= 0 max_bond= 2
# G_e 20 21 10
# 1_Qubit [22, 23] site= 22 layer= 0 max_bond= 2
# G_e 22 23 11
# 1_Qubit [24, 25] site= 24 layer= 0 max_bond= 2
# G_e 24 25 12
# 1_Qubit [26, 27] site= 26 layer= 0 max_bond= 2
# G_e 26 27 13
# 1_Qubit [28, 29] site= 28 layer= 0 max_bond= 2
# G_e 28 29 14
# 1_Qubit [30, 31] site= 30 layer= 0 max_bond= 2
# G_e 30 31 15
# ...
